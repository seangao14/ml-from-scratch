# %%
import matplotlib.pyplot as plt
from src.gda import GDA
from sklearn.datasets import make_blobs

# %%
X, y = make_blobs(100, centers=2)

# %%
plt.scatter(X[:,0], X[:,1])

# %%
gda = GDA()
gda.fit(X,y)

# %%
import numpy as np
idx = []
for i in np.unique(y):
    idx.append([j for j,k in enumerate(y) if k == i])

# %%
plt.scatter(X[idx[0],0], X[idx[0],1])
plt.scatter(X[idx[1],0], X[idx[1],1], c='g') # green is 1
test_1 = [0,-8]
plt.scatter(test_1[0], test_1[1], c='r')     # should be 1

# %%
gda.predict(test_1)
# Out:
# 1
