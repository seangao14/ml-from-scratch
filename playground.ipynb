# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # k means clustering

# %%
from sklearn.datasets import make_blobs
from src.clustering import K_means_cluster
X,y = make_blobs(100, centers=2)
# print(X)

# %%
clf = K_means_cluster()
clf.fit(X)

# %%
clf.c1, clf.c2
# Out:
# ((3.5, 2.5), (15.0, 14.0))

# %%
plt.scatter(X[clf.idx0,0], X[clf.idx0,1], c='g')
plt.scatter(X[clf.idx1,0], X[clf.idx1,1], c='b')

plt.scatter(clf.c1[0], clf.c1[1], c='r')
plt.scatter(clf.c2[0], clf.c2[1], c='r')

# %%
plt.scatter(X[:,0], X[:,1])
